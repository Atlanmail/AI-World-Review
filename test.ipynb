# %%
from app.agents.promptReviewAgent import promptReviewAgent

# %%
agent = promptReviewAgent()
agent.switch_personality("You are a grumpy old man who hates everything except things related to your dead wife, Janet, who loves puppies and flowers")

# %%
print(agent.review_content("I like cats!"))
print(agent.review_content("I like puppies!"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(agent.review_content("I like cats!"))
#       2 print(agent.review_content("I like puppies!"))
#
# File c:\Users\Trieu\OneDrive\Documents\Programming\AI World Review\app\agents\promptReviewAgent.py:49, in promptReviewAgent.review_content(self, content)
#      47 # Convert user_profile to a string for context. This can include like/dislike history, interests, etc.
#      48 prompt = self.template.invoke({"tweet_text": content, "profile_context": self.profile_context})
# ---> 49 response = self.llm.with_structured_output.invoke(prompt)
#      50 return response
#
# AttributeError: 'function' object has no attribute 'invoke'
